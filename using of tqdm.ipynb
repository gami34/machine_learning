# %% [markdown]
# <a href="https://colab.research.google.com/github/gami34/machine_learning/blob/master/using%20of%20tqdm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to install and use tqdm in python**
# ![image.png](data:image/png;base64,...)
#
# pip install tqdm
#
# pip install ipwidgets
#
# jupyter nbextension enable --py widgetsnbextension
#
# jupyter labextension install @jupyter-widgets/jupyterlab-managerpip
#
# #Note: the last command need us to have Nodejs installed v5+
#
# To activate tqdm in a notebook you just need to add a cell with,
# %%capture
# from tqdm import tqdm_notebook as tqdm
# tqdm().pandas()
#
# my_list = list(range(100))
# for x in tqdm.tqdm(my_list):
#     pass
